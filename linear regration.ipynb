# %% [markdown]
# Developing linear regression using one veriable

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('homeprices.csv')   # Given Dataset
df
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9       robinsville  2600  575000
# 10      robinsville  2900  600000
# 11      robinsville  3100  620000
# 12      robinsville  3600  695000

# %%
df=head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df=head()
#
# NameError: name 'head' is not defined

# %%
df.head()
# Out:
#               town  area   price
# 0  monroe township  2600  550000
# 1  monroe township  3000  565000
# 2  monroe township  3200  610000
# 3  monroe township  3600  680000
# 4  monroe township  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,color='red',marker='+')  # Scatter plot. We have to draw regression line

# %%
reg = linear_model.LinearRegression()      # Creating linear regression object
reg.fit(df[['area']],df[['price']])        # Fitting regression object with dataset values
# Out:
# LinearRegression()

# %% [markdown]
# prediction

# %% [markdown]
# reg.predict([[3300]])                   # Predicting price of a home with area = 3300 sqr ft

# %% [markdown]
# coefficient and regression

# %%
reg.coef_                              # This is the value of slope
# Out:
# array([[118.29495955]])

# %% [raw]
# Intersept

# %%
reg.intercept_
# Out:
# array([257056.62725576])

# %% [markdown]
# drawing regression line

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,color='blue',marker='+')
plt.plot(df.area,reg.predict(df[['area']]),color='red')  # Regression line of best fit or minimal error

# %% [markdown]
# Straight line equation

# %%
# Here, m=135.78767123, X=3300, b=180616.43835616
135.78767123*3300 + 180616.438356164    # Math behind prediction
# Out:
# 628715.753415164

# %%
prediction
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 prediction
#
# NameError: name 'prediction' is not defined

# %%
reg.predict([[5000]])                   # Predicting price of a home with area = 3300 sqr ft
# Out:
# /lib/python3.11/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[848531.42501556]])

# %% [markdown]
# Predicting price for new dataset

# %%
new_df=pd.DataFrame({'Area':[1000,2000,2500,4000]})  # new dataset
new_df
# Out:
#    Area
# 0  1000
# 1  2000
# 2  2500
# 3  4000

# %%
p=reg.predict(new_df)
p
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 p=reg.predict(new_df)
#       2 p
#
# File /lib/python3.11/site-packages/sklearn/linear_model/_base.py:386, in LinearModel.predict(self, X)
#     372 def predict(self, X):
#     373     """
#     374     Predict using the linear model.
#     375
#    (...)
#     384         Returns predicted values.
#     385     """
# --> 386     return self._decision_function(X)
#
# File /lib/python3.11/site-packages/sklearn/linear_model/_base.py:369, in LinearModel._decision_function(self, X)
#     366 def _decision_function(self, X):
#     367     check_is_fitted(self)
# --> 369     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     370     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# File /lib/python3.11/site-packages/sklearn/base.py:580, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     509 def _validate_data(
#     510     self,
#     511     X="no_validation",
#    (...)
#     516     **check_params,
#     517 ):
#     518     """Validate input data and set or check the `n_features_in_` attribute.
#     519
#     520     Parameters
#    (...)
#     578         validated.
#     579     """
# --> 580     self._check_feature_names(X, reset=reset)
#     582     if y is None and self._get_tags()["requires_y"]:
#     583         raise ValueError(
#     584             f"This {self.__class__.__name__} estimator "
#     585             "requires y to be passed, but the target y is None."
#     586         )
#
# File /lib/python3.11/site-packages/sklearn/base.py:507, in BaseEstimator._check_feature_names(self, X, reset)
#     502 if not missing_names and not unexpected_names:
#     503     message += (
#     504         "Feature names must be in the same order as they were in fit.\n"
#     505     )
# --> 507 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - Area
# Feature names seen at fit time, yet now missing:
# - area

# %%
new_df=pd.DataFrame({'area':[1000,2000,2500,4000]})  # new dataset
new_df
# Out:
#    area
# 0  1000
# 1  2000
# 2  2500
# 3  4000

# %%
p=reg.predict(new_df)
p
# Out:
# array([[375351.58680772],
#        [493646.54635968],
#        [552794.02613566],
#        [730236.4654636 ]])

# %%
new_df['PRICE']=p
new_df
# Out:
#    area          PRICE
# 0  1000  375351.586808
# 1  2000  493646.546360
# 2  2500  552794.026136
# 3  4000  730236.465464

# %% [markdown]
# converting missing dataset to csv

# %%
new_df.to_csv('predicted_dataset .csv')

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(new_df.area,new_df.price,color='green',marker='+')
plt.plot(new_df.area,reg.predict(new_df[['area']]),color='green')  # Regression line of best fit or minimal error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-29829173bbed> in ?()
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 plt.xlabel('area')
#       3 plt.ylabel('price')
# ----> 4 plt.scatter(new_df.area,new_df.price,color='green',marker='+')
#       5 plt.plot(new_df.area,reg.predict(new_df[['area']]),color='green')  # Regression line of best fit or minimal error
#
# /lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5898             and name not in self._accessors
#    5899             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'price'

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('Price')
plt.scatter(new_df.area,new_df.Price,color='green',marker='+')
plt.plot(new_df.area,reg.predict(new_df[['area']]),color='green')  # Regression line of best fit or minimal error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-b82db39d03f2> in ?()
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 plt.xlabel('area')
#       3 plt.ylabel('Price')
# ----> 4 plt.scatter(new_df.area,new_df.Price,color='green',marker='+')
#       5 plt.plot(new_df.area,reg.predict(new_df[['area']]),color='green')  # Regression line of best fit or minimal error
#
# /lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5898             and name not in self._accessors
#    5899             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Price'

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('Price')
plt.scatter(new_df.area,new_df.Price,color='red',marker='+')  # Scatter plot. We have to draw regression line
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-f77648ba5193> in ?()
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 plt.xlabel('area')
#       3 plt.ylabel('Price')
# ----> 4 plt.scatter(new_df.area,new_df.Price,color='red',marker='+')  # Scatter plot. We have to draw regression line
#
# /lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5898             and name not in self._accessors
#    5899             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Price'

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('Price')
plt.scatter(new_df.area,new_df.Price,color='green',marker='+')  # Scatter plot. We have to draw regression line
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-2dd82c8554ba> in ?()
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 plt.xlabel('area')
#       3 plt.ylabel('Price')
# ----> 4 plt.scatter(new_df.area,new_df.Price,color='green',marker='+')  # Scatter plot. We have to draw regression line
#
# /lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5898             and name not in self._accessors
#    5899             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Price'

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(new_df.area,new_df.PRICE,color='red',marker='+')  # Scatter plot. We have to draw regression line

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(new_df.area,new_df.PRICE,color='green',marker='+')
plt.plot(new_df.area,reg.predict(new_df[['area']]),color='yello')  # Regression line of best fit or minimal error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 5
#       3 plt.ylabel('price')
#       4 plt.scatter(new_df.area,new_df.PRICE,color='green',marker='+')
# ----> 5 plt.plot(new_df.area,reg.predict(new_df[['area']]),color='yello')  # Regression line of best fit or minimal error
#
# File /lib/python3.11/site-packages/matplotlib/pyplot.py:2769, in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# File /lib/python3.11/site-packages/matplotlib/axes/_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
#    1631 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
#    1634     self.add_line(line)
#
# File /lib/python3.11/site-packages/matplotlib/axes/_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     310     this += args[0],
#     311     args = args[1:]
# --> 312 yield from self._plot_args(this, kwargs)
#
# File /lib/python3.11/site-packages/matplotlib/axes/_base.py:538, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     536     return list(result)
#     537 else:
# --> 538     return [l[0] for l in result]
#
# File /lib/python3.11/site-packages/matplotlib/axes/_base.py:538, in <listcomp>(.0)
#     536     return list(result)
#     537 else:
# --> 538     return [l[0] for l in result]
#
# File /lib/python3.11/site-packages/matplotlib/axes/_base.py:531, in <genexpr>(.0)
#     528 else:
#     529     labels = [label] * n_datasets
# --> 531 result = (make_artist(x[:, j % ncx], y[:, j % ncy], kw,
#     532                       {**kwargs, 'label': label})
#     533           for j, label in enumerate(labels))
#     535 if return_kwargs:
#     536     return list(result)
#
# File /lib/python3.11/site-packages/matplotlib/axes/_base.py:351, in _process_plot_var_args._makeline(self, x, y, kw, kwargs)
#     349 default_dict = self._getdefaults(set(), kw)
#     350 self._setdefaults(default_dict, kw)
# --> 351 seg = mlines.Line2D(x, y, **kw)
#     352 return seg, kw
#
# File /lib/python3.11/site-packages/matplotlib/lines.py:370, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     367 self.set_drawstyle(drawstyle)
#     369 self._color = None
# --> 370 self.set_color(color)
#     371 self._marker = MarkerStyle(marker, fillstyle)
#     373 self._markevery = None
#
# File /lib/python3.11/site-packages/matplotlib/lines.py:1030, in Line2D.set_color(self, color)
#    1022 def set_color(self, color):
#    1023     """
#    1024     Set the color of the line.
#    1025
#    (...)
#    1028     color : color
#    1029     """
# -> 1030     mcolors._check_color_like(color=color)
#    1031     self._color = color
#    1032     self.stale = True
#
# File /lib/python3.11/site-packages/matplotlib/colors.py:130, in _check_color_like(**kwargs)
#     128 for k, v in kwargs.items():
#     129     if not is_color_like(v):
# --> 130         raise ValueError(f"{v!r} is not a valid value for {k}")
#
# ValueError: 'yello' is not a valid value for color

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(new_df.area,new_df.PRICE,color='green',marker='+')
plt.plot(new_df.area,reg.predict(new_df[['area']]),color='yello')  # Regression line of best fit or minimal error
